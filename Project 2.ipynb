# %% [markdown]
# # Project 2 Preparing Data
#
# A dataset used on this project contrains information about 160 countries with ~40 characteristics such as debt, electricity consumption, internet users an many other characteristics.
#
# The data analysis will aim to answer the following questions.
#
# ### 1st dataset - Country data
#  * What is the country with most consuption of electricity?
#  * Top 5 countries with the highest GDP
#  * What are the top 10 poorest countries?
#
# Some of the challenges to ovecome during the data preparion include:
#     * Ability to properly transform the data into csv format.
#     * Identify missing/null information in the data set.

# %%
import pandas as pd

df = pd.read_csv("https://perso.telecom-paristech.fr/eagan/class/igr204/data/factbook.csv", sep=";")
df.columns = df.columns.str.replace('-', '').str.strip().str.replace(' ', '_').str.replace('__', '_').str.replace('&', 'n').str.replace('\(kWh\)', '')

# %%
df.head()
# Out:
#        Country Area(sq_km) Birth_rate(births/1000_population)  \
# 0       String      double                             double
# 1  Afghanistan      647500                              47.02
# 2     Akrotiri         123                                NaN
# 3      Albania       28748                              15.08
# 4      Algeria     2381740                              17.13
#
#   Current_account_balance Death_rate(deaths/1000_population) Debt_external  \
# 0                  double                             double        double
# 1                     NaN                              20.75    8000000000
# 2                     NaN                                NaN           NaN
# 3              -504000000                               5.12    1410000000
# 4             11900000000                               4.60   21900000000
#
#   Electricity_consumption Electricity_production      Exports           GDP  \
# ...

# %% [markdown]
# ### Select wanted columns.

# %%
df_n = df[["Country", "Debt_external", "GDP","Reserves_of_foreign_exchange_n_gold", "Telephones_main_lines_in_use", "Telephones_mobile_cellular", "Electricity_consumption", "Electricity_production"]]

# %%
df_n.head()
# Out:
#        Country Debt_external           GDP  \
# 0       String        double        double
# 1  Afghanistan    8000000000   21500000000
# 2     Akrotiri           NaN           NaN
# 3      Albania    1410000000   17460000000
# 4      Algeria   21900000000  212300000000
#
#   Reserves_of_foreign_exchange_n_gold Telephones_main_lines_in_use  \
# 0                              double                       double
# 1                                 NaN                        33100
# 2                                 NaN                          NaN
# 3                          1206000000                       255000
# 4                         43550000000                      2199600
#
#   Telephones_mobile_cellular Electricity_consumption Electricity_production
# 0                     double                  double                 double
# 1                      15000               652200000              540000000
# ...

# %% [markdown]
# ### Remove entries that contain NaN values in any column

# %%
df_n = df_n.dropna()
df_n = df_n.drop([0])
df_n.head()
# Out:
#       Country Debt_external           GDP Reserves_of_foreign_exchange_n_gold  \
# 3     Albania    1410000000   17460000000                          1206000000
# 4     Algeria   21900000000  212300000000                         43550000000
# 7      Angola   10450000000   23170000000                           800000000
# 11  Argentina  157700000000  483500000000                         19470000000
# 12    Armenia     905000000   13650000000                           555000000
#
#    Telephones_main_lines_in_use Telephones_mobile_cellular  \
# 3                        255000                    1100000
# 4                       2199600                    1447310
# 7                         96300                     130000
# 11                      8009400                    6500000
# 12                       562600                     114400
#
#    Electricity_consumption Electricity_production
# 3               6760000000             5680000000
# ...

# %% [markdown]
# ### Find the country with the highest electricity consumption
# richest country is the one with the minumum onternal debt and highest gold reserve and GDP

# %%
df_n[df_n.Electricity_consumption == df_n.Electricity_consumption.max()]
# Out:
#     Country Debt_external          GDP Reserves_of_foreign_exchange_n_gold  \
# 184    Oman    4814000000  38090000000                          4144000000
#
#     Telephones_main_lines_in_use Telephones_mobile_cellular  \
# 184                       233900                     464900
#
#     Electricity_consumption Electricity_production
# 184              9792000000             9896000000

# %% [markdown]
# ### Top 5 countries with the highest GDP

# %%
df_n.sort_values("GDP", ascending = False, inplace = True)
df_n.head()
# Out:
#          Country Debt_external           GDP  \
# 262       Zambia    5353000000    9409000000
# 222        Spain  771100000000  937600000000
# 113      Iceland    3073000000    9373000000
# 134  Korea South  160000000000  925100000000
# 176  New Zealand   47340000000   92510000000
#
#     Reserves_of_foreign_exchange_n_gold Telephones_main_lines_in_use  \
# 262                           345000000                        88400
# 222                         19700000000                     17567500
# 113                           935000000                       190700
# 134                        199100000000                     22877000
# 176                          4805000000                      1765000
#
#     Telephones_mobile_cellular Electricity_consumption Electricity_production
# 262                     241000              5345000000             8167000000
# 222                   37506700            218400000000           229000000000
# ...

# %% [markdown]
# ### Country with the least number of active mobile phones

# %%
df_n[df_n.Telephones_mobile_cellular == df_n.Telephones_mobile_cellular.min()]
# Out:
#         Country Debt_external          GDP  \
# 142       Libya    4069000000  37480000000
# 89   Gambia The     476000000   2799000000
#
#     Reserves_of_foreign_exchange_n_gold Telephones_main_lines_in_use  \
# 142                         24180000000                       750000
# 89                            113100000                        38400
#
#     Telephones_mobile_cellular Electricity_consumption Electricity_production
# 142                     100000             19430000000            20890000000
# 89                      100000                83990000               90310000

# %% [markdown]
# ### Top 10 Poorest Countries.

# %%
df_n.sort_values("Debt_external", ascending = False, inplace = True)

# %%
df_n["Debt_external"].astype(str).astype(float).nlargest(10)
# Out:
# 249    4.710000e+12
# 250    1.400000e+12
# 120    9.139000e+11
# 222    7.711000e+11
# 44     5.700000e+11
# 110    4.176000e+11
# 15     3.087000e+11
# 195    2.747000e+11
# 50     2.333000e+11
# 34     2.198000e+11
# Name: Debt_external, dtype: float64

# %% [markdown]
# ### 2nd Data Set
#
# #### Olympics Data
#
# Clean up column header. Set row 2 as column column header.

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/realpython/python-data-cleaning/master/Datasets/olympics.csv", header=1)
df2.columns = df2.columns.str.replace('!', '').str.strip()
df2.head()
# Out:
#                 Unnamed: 0  ? Summer  01  02  03  Total  ? Winter  01 .1  \
# 0        Afghanistan (AFG)        13   0   0   2      2         0      0
# 1            Algeria (ALG)        12   5   2   8     15         3      0
# 2          Argentina (ARG)        23  18  24  28     70        18      0
# 3            Armenia (ARM)         5   1   2   9     12         6      0
# 4  Australasia (ANZ) [ANZ]         2   3   4   5     12         0      0
#
#    02 .1  03 .1  Total.1  ? Games  01 .2  02 .2  03 .2  Combined total
# 0      0      0        0       13      0      0      2               2
# 1      0      0        0       15      5      2      8              15
# 2      0      0        0       41     18     24     28              70
# 3      0      0        0       11      1      2      9              12
# 4      0      0        0        2      3      4      5              12

# %%
df2.columns = df2.columns.str.replace('?', '').str.replace('Unnamed: 0', 'Country')

# %%
df2.head()
# Out:
#                    Country   Summer  01  02  03  Total   Winter  01 .1  02 .1  \
# 0        Afghanistan (AFG)       13   0   0   2      2        0      0      0
# 1            Algeria (ALG)       12   5   2   8     15        3      0      0
# 2          Argentina (ARG)       23  18  24  28     70       18      0      0
# 3            Armenia (ARM)        5   1   2   9     12        6      0      0
# 4  Australasia (ANZ) [ANZ]        2   3   4   5     12        0      0      0
#
#    03 .1  Total.1   Games  01 .2  02 .2  03 .2  Combined total
# 0      0        0      13      0      0      2               2
# 1      0        0      15      5      2      8              15
# 2      0        0      41     18     24     28              70
# 3      0        0      11      1      2      9              12
# 4      0        0       2      3      4      5              12

# %% [markdown]
# ### Country with the most olympic medals during the summer olympics

# %%
#Remove totals row
df2.drop(df2.tail(1).index,inplace=True)

# %%
df2.sort_values(by='Total', ascending=False)
# Out:
#                                   Country   Summer   01   02   03  Total  \
# 135   United States (USA) [P] [Q] [R] [Z]       26  976  757  666   2399
# 106              Soviet Union (URS) [URS]        9  395  319  296   1010
# 49          Great Britain (GBR) [GBR] [Z]       27  236  272  272    780
# 41               France (FRA) [O] [P] [Z]       27  202  223  246    671
# 44                Germany (GER) [GER] [Z]       15  174  182  217    573
# 64                    Italy (ITA) [M] [S]       26  198  166  185    549
# 120                      Sweden (SWE) [Z]       26  143  164  176    483
# 56                          Hungary (HUN)       25  167  144  165    476
# 23                      China (CHN) [CHN]        9  201  146  126    473
# 5               Australia (AUS) [AUS] [Z]       25  139  152  177    468
# 46               East Germany (GDR) [GDR]        5  153  129  127    409
# 66                            Japan (JPN)       21  130  126  142    398
# ...

# %% [markdown]
# United States was the country with the most medals.

# %% [markdown]
# ### #rd Data Set Application Data
# https://bbhosted.cuny.edu/courses/1/SPS01_IS_362_01_1199_1/db/_33932222_1/job_app_status.csv
# Display all candidates pending technical interview

# %%
df3 = pd.read_csv("job_app_status.csv")
df3.columns= df3.columns.str.replace(' ', '_')
df3.head()
# Out:
#    App_Index   Job_Type Application_Date     Status Interview_Scheduled  \
# 0          1  Full Time         5/1/2019  Not Hired           6/30/2019
# 1          2  Full Time        5/30/2019      Hired           7/29/2019
# 2          3  Full Time        6/16/2019      Hired           8/15/2019
# 3          4  Full Time         2/3/2019  Not Hired            4/4/2019
# 4          5  Full Time         3/9/2019      Hired            5/8/2019
#
#   Resume_check Background_check Manager_Interview_Scheduled  \
# 0    Completed         Required                   Completed
# 1    Completed        Completed                   Completed
# 2    Completed        Completed                   Completed
# 3     Required         Required                   Completed
# 4    Completed        Completed                   Completed
#
#   Technical_Interview HR_Interview Offer_or_Reject_Email Last_Updated
# 0            Required    Completed                Reject    9/29/2019
# ...

# %%
#df3.loc[df3['Technical Interview'] == "Pending" ]
df3.loc[df3['Status'].isin(['Pending Interviews']) & df3['Technical_Interview'].isin(['Required'])]
# Out:
#      App_Index    Job_Type Application_Date              Status  \
# 7            8  Consultant        1/24/2019  Pending Interviews
# 16          17  Consultant         2/3/2019  Pending Interviews
# 30          31  Consultant         3/9/2019  Pending Interviews
# 43          44  Consultant         3/9/2019  Pending Interviews
# 77          78  Consultant        5/24/2019  Pending Interviews
# 89          90  Consultant         7/3/2019  Pending Interviews
# 95          96  Consultant         3/9/2019  Pending Interviews
# 107        108  Consultant         2/3/2019  Pending Interviews
# 111        112  Consultant        2/24/2019  Pending Interviews
# 114        115  Consultant        4/25/2019  Pending Interviews
# 134        135  Consultant         3/9/2019  Pending Interviews
# 168        169  Consultant        5/24/2019  Pending Interviews
# 176        177  Consultant        4/26/2019  Pending Interviews
# 193        194  Consultant         7/3/2019  Pending Interviews
# ...

# %% [markdown]
# ### Find total amount of candidate hired during the month of March 2019

# %%
import datetime
datetime.datetime.strptime
df_hired = df3.loc[df3['Status'].isin(['Hired']) & (df3.Application_Date.between('3/1/2019', '3/31/2019'))]

# %%
df_hired.sort_values('Application_Date', ascending=False)
# Out:
#      App_Index   Job_Type Application_Date Status Interview_Scheduled  \
# 541        542  Full Time         3/3/2019  Hired            5/2/2019
# 567        568  Full Time         3/3/2019  Hired            5/2/2019
# 906        907  Full Time        3/24/2019  Hired           5/23/2019
# 854        855  Full Time        3/24/2019  Hired           5/23/2019
# 841        842  Full Time        3/24/2019  Hired           5/23/2019
# 815        816  Full Time        3/24/2019  Hired           5/23/2019
# 685        686  Full Time        3/24/2019  Hired           5/23/2019
# 646        647  Full Time        3/24/2019  Hired           5/23/2019
# 9           10  Full Time        3/24/2019  Hired           5/23/2019
# 22          23  Full Time        3/24/2019  Hired           5/23/2019
# 425        426  Full Time        3/24/2019  Hired           5/23/2019
# 321        322  Full Time        3/24/2019  Hired           5/23/2019
# ...
